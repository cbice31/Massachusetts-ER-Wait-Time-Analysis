# %% [markdown]
# # Massachusetts ER Wait Time Analysis
#
# ## 01 — Data Cleaning
#
# This notebook cleans the raw CHIA ED length-of-stay (LOS) dataset and outputs a cleaned file to `data/processed/df_clean.csv` for downstream analysis.
#
# > **Note:** Raw/processed data is ignored by git. Place raw files in `data/raw/` as described in the README.

# %% [markdown]
# ## Setup/Imports

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

# %%
df = pd.read_excel("LOS_data.xlsx",sheet_name = 'II-1', skiprows = 7)
df
# Out:
#       Year (FFY)          Month                 Emergency Department  Visits  \
# 0           2019   October 2018                           All Visits  202625
# 1           2019   October 2018                 Anna Jaques Hospital    1629
# 2           2019   October 2018              Athol Memorial Hospital     854
# 3           2019   October 2018     Baystate Franklin Medical Center    1709
# 4           2019   October 2018              Baystate Medical Center    7025
# ...          ...            ...                                  ...     ...
# 4443        2021  February 2021                    Fairview Hospital     628
# 4444        2020     March 2020                 Mercy Medical Center    4199
# 4445        2020     March 2020  Massachusetts Eye and Ear Infirmary    1270
# 4446        2020      June 2020  Massachusetts Eye and Ear Infirmary    1390
# 4447        2020     April 2020  Massachusetts Eye and Ear Infirmary     891
#
#      Percent of Total Visits within Month Average Length of Stay (Hours)
# 0                                 100.00%                       4.239666
# 1                                   0.80%                       2.899785
# 2                                   0.42%                       3.469106
# 3                                   0.84%                       3.660659
# 4                                   3.46%                       5.606492
# ...                                   ...                            ...
# 4443                                0.48%                       2.060828
# 4444                                2.67%                         2.0503
# 4445                                0.80%                       2.028989
# 4446                                1.00%                       1.947998
# 4447                                0.93%                       1.946932
#
# [4448 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4448 entries, 0 to 4447
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Year (FFY)                            4448 non-null   int64
#  1   Month                                 4448 non-null   object
#  2   Emergency Department                  4448 non-null   object
#  3   Visits                                4448 non-null   int64
#  4   Percent of Total Visits within Month  4448 non-null   object
#  5   Average Length of Stay (Hours)        4448 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 208.6+ KB

# %% [markdown]
# ## Data Cleaning

# %%
# change column names for ease of analysis
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

#rename columns
df.rename(columns = {'average_length_of_stay_(hours)':'average_los_hours'}, inplace = True)
df.rename(columns = {'percent_of_total_visits_within_month':'pct_monthly_visits'}, inplace = True)

#change datatypes
df['month'] = pd.to_datetime(df['month'], format="%B %Y")
df['visits'] = pd.to_numeric(df['visits'])
df['average_los_hours'] = pd.to_numeric(df['average_los_hours'], errors = 'coerce')

#convert pct to a float
df["pct_monthly_visits"] = (
    df["pct_monthly_visits"]
    .str.replace('%', '', regex=False)
    .astype(float) / 100
)

# %%
df['emergency_department'].nunique()
# Out:
# 59

# %%
# assign hospital system to each hospital (found online)

system_map = {
    "Massachusetts General Hospital": "Mass General Brigham",
    "Brigham and Women's Hospital": "Mass General Brigham",
    "Newton-Wellesley Hospital": "Mass General Brigham",
    "Cooley Dickinson Hospital": "Mass General Brigham",
    "Massachusetts Eye and Ear Infirmary": "Mass General Brigham",
    "Beth Israel Deaconess Medical Center": "Beth Israel Lahey Health",
    "Lahey Hospital & Medical Center": "Beth Israel Lahey Health",
    "Beth Israel Deaconess Hospital - Milton": "Beth Israel Lahey Health",
    "Beth Israel Deaconess Hospital - Needham": "Beth Israel Lahey Health",
    "Beth Israel Deaconess Hospital - Plymouth": "Beth Israel Lahey Health",
    "Mount Auburn Hospital": "Beth Israel Lahey Health",
    "Tufts Medical Center": "Tufts Medicine",
    "UMass Memorial Medical Center": "UMass Memorial Health",
    "Marlborough Hospital": "UMass Memorial Health",
    "HealthAlliance-Clinton Hospital": "UMass Memorial Health",
    "Baystate Medical Center": "Baystate Health",
    "Baystate Franklin Medical Center": "Baystate Health",
    "Baystate Noble Hospital": "Baystate Health",
    "Baystate Wing Hospital": "Baystate Health",
    "Southcoast Hospitals Group": "Southcoast Health",
    "South Shore Hospital": "South Shore Health",
    "Cape Cod Hospital": "Cape Cod Healthcare",
    "Falmouth Hospital": "Cape Cod Healthcare",
    "Cambridge Health Alliance": "CHA",
    "Boston Medical Center": "BMC Health System",
    "Boston Children's Hospital": "Boston Children’s",
    "Lawrence General Hospital": "Independent",
    "Sturdy Memorial Hospital": "Independent",
    "Emerson Hospital": "Independent",
    "Nantucket Cottage Hospital": "Mass General Brigham",
    "Martha's Vineyard Hospital": "Mass General Brigham",
    "North Shore Medical Center": "Mass General Brigham",
    "Lahey Hospital & Medical Center": "Beth Israel Lahey Health",
    "Signature Healthcare Brockton Hospital": "Signature Healthcare",
    "Saint Vincent Hospital": "Tenet Healthcare",
    "MetroWest Medical Center": "Tenet Healthcare",
    "Holy Family Hospital": "Steward Health Care",
    "Saint Anne's Hospital": "Steward Health Care",
    "Steward Carney Hospital": "Steward Health Care",
    "Steward Norwood Hospital": "Steward Health Care",
    "Morton Hospital": "Steward Health Care",
    "Northeast Hospital": "Beth Israel Lahey Health",  # legacy name
    "Heywood Hospital": "Independent",
    "Harrington Memorial Hospital": "Independent",
    "Fairview Hospital": "Berkshire Health Systems",
    "Berkshire Medical Center": "Berkshire Health Systems",
    "Milford Regional Medical Center": "Independent",
    "MelroseWakefield Hospital": "Tufts Medicine",
    "Anna Jaques Hospital": "Beth Israel Lahey Health",
    "Nashoba Valley Medical Center": "Prime Healthcare",
    "Athol Memorial Hospital": "Heywood Healthcare",
    "Boston Medical Center - Brighton": "Boston Medical Center Health System",
    "Boston Medical Center - South": "Boston Medical Center Health System",
    "Brigham and Women's Faulkner Hospital": "Mass General Brigham",
    "Holyoke Medical Center": "Valley Health Systems (Independent)",
    "Lowell General Hospital": "Tufts Medicine",
    "Mercy Medical Center": "Trinity Health",
    "Winchester Hospital": "Beth Israel Lahey Health",
    "North Adams Regional Hospital": "Closed/Legacy (Berkshire Health Systems)"
}

df["hospital_system"] = df["emergency_department"].map(system_map)

# See any hospitals not mapped yet:
unmapped = df.loc[df["hospital_system"].isna(), "emergency_department"].unique()
unmapped
# Out:
# array(['All Visits'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4448 entries, 0 to 4447
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year_(ffy)            4448 non-null   int64
#  1   month                 4448 non-null   datetime64[ns]
#  2   emergency_department  4448 non-null   object
#  3   visits                4448 non-null   int64
#  4   pct_monthly_visits    4448 non-null   float64
#  5   average_los_hours     4400 non-null   float64
#  6   hospital_system       4370 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 243.4+ KB

# %%
# location csv generated from  chatgpt 
df_loc = pd.read_csv('/Users/chrisbice/Desktop/Data Projects/ER Wait-Time Analysis/ma_hospital_locations_complete.csv')

# %%
df_loc
# Out:
#                          emergency_department              city  latitude  \
# 0                        Anna Jaques Hospital       Newburyport   42.8120
# 1                     Athol Memorial Hospital             Athol   42.5953
# 2            Baystate Franklin Medical Center        Greenfield   42.5879
# 3                     Baystate Noble Hospital         Westfield   42.1215
# 4                      Baystate Wing Hospital            Palmer   42.1584
# 5                    Berkshire Medical Center        Pittsfield   42.4534
# 6     Beth Israel Deaconess Hospital - Milton            Milton   42.2495
# 7    Beth Israel Deaconess Hospital - Needham           Needham   42.2816
# 8   Beth Israel Deaconess Hospital - Plymouth          Plymouth   41.9570
# 9        Beth Israel Deaconess Medical Center            Boston   42.3370
# 10                 Boston Children's Hospital            Boston   42.3374
# 11           Boston Medical Center - Brighton          Brighton   42.3503
# 12              Boston Medical Center - South           Roxbury   42.3337
# 13                      Boston Medical Center            Boston   42.3345
# 14      Brigham and Women's Faulkner Hospital     Jamaica Plain   42.3009
# 15               Brigham and Women's Hospital            Boston   42.3364
# 16                  Cambridge Health Alliance         Cambridge   42.3740
# 17                          Cape Cod Hospital           Hyannis   41.6548
# 18                  Cooley Dickinson Hospital       Northampton   42.3242
# 19                           Emerson Hospital           Concord   42.4456
# 20                          Fairview Hospital  Great Barrington   42.1968
# 21                          Falmouth Hospital          Falmouth   41.5785
# 22               Harrington Memorial Hospital       Southbridge   42.0751
# 23                           Heywood Hospital           Gardner   42.5754
# 24                       Holy Family Hospital           Methuen   42.7305
# 25                     Holyoke Medical Center           Holyoke   42.2053
# 26            Lahey Hospital & Medical Center        Burlington   42.5046
# 27                  Lawrence General Hospital          Lawrence   42.7034
# 28                    Lowell General Hospital            Lowell   42.6440
# 29                 Martha's Vineyard Hospital    Vineyard Haven   41.4543
# 30        Massachusetts Eye and Ear Infirmary            Boston   42.3630
# 31                  MelroseWakefield Hospital           Melrose   42.4550
# 32                       Mercy Medical Center       Springfield   42.1029
# 33            Milford Regional Medical Center           Milford   42.1406
# 34                            Morton Hospital           Taunton   41.9018
# 35                      Mount Auburn Hospital         Cambridge   42.3740
# 36                 Nantucket Cottage Hospital         Nantucket   41.2812
# 37              Nashoba Valley Medical Center              Ayer   42.5618
# 38                  Newton-Wellesley Hospital            Newton   42.3318
# 39              North Adams Regional Hospital       North Adams   42.6998
# 40                 North Shore Medical Center             Salem   42.5168
# 41                         Northeast Hospital           Beverly   42.5584
# 42                      Saint Anne's Hospital        Fall River   41.6987
# 43                     Saint Vincent Hospital         Worcester   42.2614
# 44     Signature Healthcare Brockton Hospital          Brockton   42.0826
# 45                       South Shore Hospital    South Weymouth   42.1687
# 46                 Southcoast Hospitals Group       New Bedford   41.6362
# 47                    Steward Carney Hospital        Dorchester   42.2898
# 48                   Steward Norwood Hospital           Norwood   42.1852
# 49                   Sturdy Memorial Hospital         Attleboro   41.9450
# 50                       Tufts Medical Center            Boston   42.3492
# 51              UMass Memorial Medical Center         Worcester   42.2768
# 52                        Winchester Hospital        Winchester   42.4515
# 53                   MetroWest Medical Center        Framingham   42.2979
#
#     longitude                          system_name            region
# 0    -70.8717             Beth Israel Lahey Health       North Shore
# 1    -72.2266                   Heywood Healthcare        Central MA
# 2    -72.6007                      Baystate Health        Western MA
# 3    -72.7600                      Baystate Health        Western MA
# 4    -72.3306                      Baystate Health        Western MA
# 5    -73.2540             Berkshire Health Systems        Western MA
# 6    -71.0656             Beth Israel Lahey Health       South Shore
# 7    -71.2410             Beth Israel Lahey Health      Boston Metro
# 8    -70.6790             Beth Israel Lahey Health       South Shore
# 9    -71.1057             Beth Israel Lahey Health      Boston Metro
# 10   -71.1050               Independent (Academic)      Boston Metro
# 11   -71.1501  Boston Medical Center Health System      Boston Metro
# 12   -71.0830  Boston Medical Center Health System      Boston Metro
# 13   -71.0686  Boston Medical Center Health System      Boston Metro
# 14   -71.1253                 Mass General Brigham      Boston Metro
# 15   -71.1042                 Mass General Brigham      Boston Metro
# 16   -71.1097                           CHA Health      Boston Metro
# 17   -70.2890                  Cape Cod Healthcare    Cape & Islands
# 18   -72.6371                 Mass General Brigham        Western MA
# 19   -71.3744                          Independent         MetroWest
# 20   -73.3634             Berkshire Health Systems        Western MA
# 21   -70.6163                  Cape Cod Healthcare    Cape & Islands
# 22   -72.0338                UMass Memorial Health        Central MA
# 23   -71.9959                   Heywood Healthcare        Central MA
# 24   -71.1909                  Steward Health Care  Merrimack Valley
# 25   -72.6412                Valley Health Systems        Western MA
# 26   -71.1910             Beth Israel Lahey Health       North Shore
# 27   -71.1607                          Independent  Merrimack Valley
# 28   -71.3232                       Tufts Medicine  Merrimack Valley
# 29   -70.6037                 Mass General Brigham    Cape & Islands
# 30   -71.0688                 Mass General Brigham      Boston Metro
# 31   -71.0535             Beth Israel Lahey Health       North Shore
# 32   -72.5787                       Trinity Health        Western MA
# 33   -71.5167                          Independent        Central MA
# 34   -71.0896                  Steward Health Care       South Coast
# 35   -71.1310             Beth Israel Lahey Health      Boston Metro
# 36   -70.1001                 Mass General Brigham    Cape & Islands
# 37   -71.5890                  Steward Health Care       North Shore
# 38   -71.2452                 Mass General Brigham      Boston Metro
# 39   -73.1087            Closed (Berkshire Health)        Western MA
# 40   -70.8973                 Mass General Brigham       North Shore
# 41   -70.8801             Beth Israel Lahey Health       North Shore
# 42   -71.1547                  Steward Health Care       South Coast
# 43   -71.8022                     Tenet Healthcare        Central MA
# 44   -71.0395                 Signature Healthcare       South Shore
# 45   -70.9499                   South Shore Health       South Shore
# 46   -70.9342                    Southcoast Health       South Coast
# 47   -71.0688                  Steward Health Care      Boston Metro
# 48   -71.1995                  Steward Health Care       South Shore
# 49   -71.2879                          Independent       South Coast
# 50   -71.0637                       Tufts Medicine      Boston Metro
# 51   -71.7620                UMass Memorial Health        Central MA
# 52   -71.1419             Beth Israel Lahey Health       North Shore
# 53   -71.4372                     Tenet Healthcare         MetroWest

# %%
# merge data frames 
df = df.merge(df_loc, on = 'emergency_department', how = 'left')
df
# Out:
#       year_(ffy)      month                 emergency_department  visits  \
# 0           2019 2018-10-01                           All Visits  202625
# 1           2019 2018-10-01                 Anna Jaques Hospital    1629
# 2           2019 2018-10-01              Athol Memorial Hospital     854
# 3           2019 2018-10-01     Baystate Franklin Medical Center    1709
# 4           2019 2018-10-01              Baystate Medical Center    7025
# ...          ...        ...                                  ...     ...
# 4443        2021 2021-02-01                    Fairview Hospital     628
# 4444        2020 2020-03-01                 Mercy Medical Center    4199
# 4445        2020 2020-03-01  Massachusetts Eye and Ear Infirmary    1270
# 4446        2020 2020-06-01  Massachusetts Eye and Ear Infirmary    1390
# 4447        2020 2020-04-01  Massachusetts Eye and Ear Infirmary     891
#
#       pct_monthly_visits  average_los_hours           hospital_system  \
# 0                 1.0000           4.239666                       NaN
# 1                 0.0080           2.899785  Beth Israel Lahey Health
# 2                 0.0042           3.469106        Heywood Healthcare
# 3                 0.0084           3.660659           Baystate Health
# 4                 0.0346           5.606492           Baystate Health
# ...                  ...                ...                       ...
# 4443              0.0048           2.060828  Berkshire Health Systems
# 4444              0.0267           2.050300            Trinity Health
# 4445              0.0080           2.028989      Mass General Brigham
# 4446              0.0100           1.947998      Mass General Brigham
# 4447              0.0093           1.946932      Mass General Brigham
#
#                   city  latitude  longitude               system_name  \
# 0                  NaN       NaN        NaN                       NaN
# 1          Newburyport   42.8120   -70.8717  Beth Israel Lahey Health
# 2                Athol   42.5953   -72.2266        Heywood Healthcare
# 3           Greenfield   42.5879   -72.6007           Baystate Health
# 4                  NaN       NaN        NaN                       NaN
# ...                ...       ...        ...                       ...
# 4443  Great Barrington   42.1968   -73.3634  Berkshire Health Systems
# 4444       Springfield   42.1029   -72.5787            Trinity Health
# 4445            Boston   42.3630   -71.0688      Mass General Brigham
# 4446            Boston   42.3630   -71.0688      Mass General Brigham
# 4447            Boston   42.3630   -71.0688      Mass General Brigham
#
#             region
# 0              NaN
# 1      North Shore
# 2       Central MA
# 3       Western MA
# 4              NaN
# ...            ...
# 4443    Western MA
# 4444    Western MA
# 4445  Boston Metro
# 4446  Boston Metro
# 4447  Boston Metro
#
# [4448 rows x 12 columns]

# %%
# drop redundant column 'system_name' and fiscal year
df.drop('system_name', axis = 1,inplace = True)
df.drop('year_(ffy)',axis = 1,inplace = True)

# %%
# identify entries with missing geolocation
missing_geo = df[(df['city'].isnull()) & (df['emergency_department'] != 'All Visits')]
missing_geo['emergency_department'].unique()
# Out:
# array(['Baystate Medical Center', 'HealthAlliance-Clinton Hospital',
#        'Marlborough Hospital', 'Massachusetts General Hospital'],
#       dtype=object)

# %%
#manually fill in the missing hospital data
df.loc[df['emergency_department'] == "Baystate Medical Center", ['city', 'latitude', 'longitude', 'region']] = [
    "Springfield", 42.12171362154685, -72.60298297011474, "Western MA"

]
df.loc[df['emergency_department'] == "HealthAlliance-Clinton Hospital", ['city', 'latitude', 'longitude', 'region']] = [
    "Clinton", 42.427672202512646, -71.69325696064523, "Central MA"

]
df.loc[df['emergency_department'] == "Marlborough Hospital", ['city', 'latitude', 'longitude', 'region']] = [
    "Clinton", 42.35488421278838, -71.55505223181254, "MetroWest"

]
df.loc[df['emergency_department'] == "Massachusetts General Hospital", ['city', 'latitude', 'longitude', 'region']] = [
    "Boston", 42.362607817712124, -71.06838040221002, "Boston Metro"

]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4448 entries, 0 to 4447
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   month                 4448 non-null   datetime64[ns]
#  1   emergency_department  4448 non-null   object
#  2   visits                4448 non-null   int64
#  3   pct_monthly_visits    4448 non-null   float64
#  4   average_los_hours     4400 non-null   float64
#  5   hospital_system       4370 non-null   object
#  6   city                  4370 non-null   object
#  7   latitude              4370 non-null   float64
#  8   longitude             4370 non-null   float64
#  9   region                4370 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 347.6+ KB

# %%
df[df['average_los_hours'].isna()]
# Out:
#          month      emergency_department  visits  pct_monthly_visits  \
# 697 2019-10-01  MetroWest Medical Center    3727              0.0187
# 698 2019-10-01    Saint Vincent Hospital    4767              0.0239
# 699 2019-11-01  MetroWest Medical Center    3517              0.0189
# 700 2019-11-01    Saint Vincent Hospital    4356              0.0234
# 701 2019-12-01  MetroWest Medical Center    3967              0.0201
# 702 2019-12-01    Saint Vincent Hospital    4428              0.0225
# 703 2020-01-01  MetroWest Medical Center    4116              0.0192
# 704 2020-01-01    Saint Vincent Hospital    5032              0.0234
# 705 2020-02-01  MetroWest Medical Center    3596              0.0185
# 706 2020-02-01    Saint Vincent Hospital    4518              0.0232
# 707 2020-03-01  MetroWest Medical Center    2999              0.0191
# 708 2020-03-01    Saint Vincent Hospital    3665              0.0233
# 709 2020-04-01  MetroWest Medical Center    1791              0.0187
# 710 2020-04-01    Saint Vincent Hospital    2309              0.0241
# 711 2020-05-01  MetroWest Medical Center    2157              0.0179
# 712 2020-05-01    Saint Vincent Hospital    2856              0.0237
# 713 2020-06-01  MetroWest Medical Center    2360              0.0170
# 714 2020-06-01    Saint Vincent Hospital    2866              0.0206
# 715 2020-07-01  MetroWest Medical Center    2592              0.0161
# 716 2020-07-01    Saint Vincent Hospital    3633              0.0227
# 717 2020-08-01  MetroWest Medical Center    2774              0.0168
# 718 2020-08-01    Saint Vincent Hospital    3682              0.0224
# 719 2020-09-01  MetroWest Medical Center    2612              0.0169
# 720 2020-09-01    Saint Vincent Hospital    3420              0.0221
# 721 2020-10-01  MetroWest Medical Center    2433              0.0158
# 722 2020-10-01    Saint Vincent Hospital    3542              0.0230
# 723 2020-11-01  MetroWest Medical Center    2297              0.0156
# 724 2020-11-01    Saint Vincent Hospital    3314              0.0225
# 725 2020-12-01  MetroWest Medical Center    2184              0.0149
# 726 2020-12-01    Saint Vincent Hospital    3175              0.0217
# 727 2021-01-01  MetroWest Medical Center    2134              0.0147
# 728 2021-01-01    Saint Vincent Hospital    3319              0.0229
# 729 2021-02-01  MetroWest Medical Center    1995              0.0153
# 730 2021-02-01    Saint Vincent Hospital    2912              0.0223
# 731 2021-03-01  MetroWest Medical Center    2373              0.0155
# 732 2021-03-01    Saint Vincent Hospital    2986              0.0195
# 733 2021-04-01  MetroWest Medical Center    2460              0.0152
# 734 2021-04-01    Saint Vincent Hospital    3287              0.0204
# 735 2021-05-01  MetroWest Medical Center    2777              0.0156
# 736 2021-05-01    Saint Vincent Hospital    3432              0.0193
# 737 2021-06-01  MetroWest Medical Center    2805              0.0151
# 738 2021-06-01    Saint Vincent Hospital    3564              0.0192
# 739 2021-07-01  MetroWest Medical Center    2915              0.0149
# 740 2021-07-01    Saint Vincent Hospital    3821              0.0196
# 741 2021-08-01  MetroWest Medical Center    2952              0.0150
# 742 2021-08-01    Saint Vincent Hospital    3782              0.0192
# 743 2021-09-01  MetroWest Medical Center    2819              0.0149
# 744 2021-09-01    Saint Vincent Hospital    3663              0.0193
#
#      average_los_hours   hospital_system        city  latitude  longitude  \
# 697                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 698                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 699                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 700                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 701                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 702                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 703                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 704                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 705                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 706                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 707                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 708                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 709                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 710                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 711                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 712                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 713                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 714                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 715                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 716                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 717                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 718                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 719                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 720                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 721                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 722                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 723                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 724                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 725                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 726                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 727                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 728                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 729                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 730                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 731                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 732                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 733                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 734                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 735                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 736                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 737                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 738                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 739                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 740                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 741                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 742                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
# 743                NaN  Tenet Healthcare  Framingham   42.2979   -71.4372
# 744                NaN  Tenet Healthcare   Worcester   42.2614   -71.8022
#
#          region
# 697   MetroWest
# 698  Central MA
# 699   MetroWest
# 700  Central MA
# 701   MetroWest
# 702  Central MA
# 703   MetroWest
# 704  Central MA
# 705   MetroWest
# 706  Central MA
# 707   MetroWest
# 708  Central MA
# 709   MetroWest
# 710  Central MA
# 711   MetroWest
# 712  Central MA
# 713   MetroWest
# 714  Central MA
# 715   MetroWest
# 716  Central MA
# 717   MetroWest
# 718  Central MA
# 719   MetroWest
# 720  Central MA
# 721   MetroWest
# 722  Central MA
# 723   MetroWest
# 724  Central MA
# 725   MetroWest
# 726  Central MA
# 727   MetroWest
# 728  Central MA
# 729   MetroWest
# 730  Central MA
# 731   MetroWest
# 732  Central MA
# 733   MetroWest
# 734  Central MA
# 735   MetroWest
# 736  Central MA
# 737   MetroWest
# 738  Central MA
# 739   MetroWest
# 740  Central MA
# 741   MetroWest
# 742  Central MA
# 743   MetroWest
# 744  Central MA

# %%
# Make a safe copy
df_filled = df.copy()

# Hospitals with missing LOS
target_hospitals = [
    "MetroWest Medical Center",
    "Saint Vincent Hospital"
]

for hospital in target_hospitals:
    
    # Subset hospital data
    hosp_df = df_filled[df_filled["emergency_department"] == hospital].copy()
    
    # Split into known and missing LOS
    train = hosp_df[hosp_df["average_los_hours"].notna()]
    missing = hosp_df[hosp_df["average_los_hours"].isna()]
    
    # Skip if no missing values
    if len(missing) == 0:
        continue
    
    # -------------------------------
    # Train regression: LOS ~ Visits
    # -------------------------------
    X_train = train[["visits"]]
    y_train = train["average_los_hours"]
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # -------------------------------
    # Predict missing LOS
    # -------------------------------
    X_missing = missing[["visits"]]
    predicted_los = model.predict(X_missing)
    
    # -------------------------------
    # Fill values back into main DF
    # -------------------------------
    df.loc[
        (df["emergency_department"] == hospital) &
        (df["average_los_hours"].isna()),
        "average_los_hours"
    ] = predicted_los

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4448 entries, 0 to 4447
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   month                 4448 non-null   datetime64[ns]
#  1   emergency_department  4448 non-null   object
#  2   visits                4448 non-null   int64
#  3   pct_monthly_visits    4448 non-null   float64
#  4   average_los_hours     4448 non-null   float64
#  5   hospital_system       4370 non-null   object
#  6   city                  4370 non-null   object
#  7   latitude              4370 non-null   float64
#  8   longitude             4370 non-null   float64
#  9   region                4370 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 347.6+ KB

# %%
df.loc[697:701]
# Out:
#          month      emergency_department  visits  pct_monthly_visits  \
# 697 2019-10-01  MetroWest Medical Center    3727              0.0187
# 698 2019-10-01    Saint Vincent Hospital    4767              0.0239
# 699 2019-11-01  MetroWest Medical Center    3517              0.0189
# 700 2019-11-01    Saint Vincent Hospital    4356              0.0234
# 701 2019-12-01  MetroWest Medical Center    3967              0.0201
#
#      average_los_hours   hospital_system        city  latitude  longitude  \
# 697           4.343740  Tenet Healthcare  Framingham   42.2979   -71.4372
# 698           4.779541  Tenet Healthcare   Worcester   42.2614   -71.8022
# 699           4.567416  Tenet Healthcare  Framingham   42.2979   -71.4372
# 700           4.946924  Tenet Healthcare   Worcester   42.2614   -71.8022
# 701           4.088110  Tenet Healthcare  Framingham   42.2979   -71.4372
#
#          region
# 697   MetroWest
# 698  Central MA
# 699   MetroWest
# 700  Central MA
# 701   MetroWest

# %%
corrs = (
    df.groupby("emergency_department")[["visits", "average_los_hours"]]
      .corr()
      .iloc[0::2, -1]             # extract the correlation values
      .rename("correlation")
)

# merge back into your main dataframe
df = df.merge(corrs, on="emergency_department", how="left")

df
# Out:
#           month                 emergency_department  visits  \
# 0    2018-10-01                           All Visits  202625
# 1    2018-10-01                 Anna Jaques Hospital    1629
# 2    2018-10-01              Athol Memorial Hospital     854
# 3    2018-10-01     Baystate Franklin Medical Center    1709
# 4    2018-10-01              Baystate Medical Center    7025
# ...         ...                                  ...     ...
# 4443 2021-02-01                    Fairview Hospital     628
# 4444 2020-03-01                 Mercy Medical Center    4199
# 4445 2020-03-01  Massachusetts Eye and Ear Infirmary    1270
# 4446 2020-06-01  Massachusetts Eye and Ear Infirmary    1390
# 4447 2020-04-01  Massachusetts Eye and Ear Infirmary     891
#
#       pct_monthly_visits  average_los_hours           hospital_system  \
# 0                 1.0000           4.239666                       NaN
# 1                 0.0080           2.899785  Beth Israel Lahey Health
# 2                 0.0042           3.469106        Heywood Healthcare
# 3                 0.0084           3.660659           Baystate Health
# 4                 0.0346           5.606492           Baystate Health
# ...                  ...                ...                       ...
# 4443              0.0048           2.060828  Berkshire Health Systems
# 4444              0.0267           2.050300            Trinity Health
# 4445              0.0080           2.028989      Mass General Brigham
# 4446              0.0100           1.947998      Mass General Brigham
# 4447              0.0093           1.946932      Mass General Brigham
#
#                   city   latitude  longitude        region  correlation
# 0                  NaN        NaN        NaN           NaN    -0.094358
# 1          Newburyport  42.812000 -70.871700   North Shore    -0.275977
# 2                Athol  42.595300 -72.226600    Central MA     0.104899
# 3           Greenfield  42.587900 -72.600700    Western MA    -0.141135
# 4          Springfield  42.121714 -72.602983    Western MA    -0.100213
# ...                ...        ...        ...           ...          ...
# 4443  Great Barrington  42.196800 -73.363400    Western MA     0.476108
# 4444       Springfield  42.102900 -72.578700    Western MA    -0.762083
# 4445            Boston  42.363000 -71.068800  Boston Metro     0.699062
# 4446            Boston  42.363000 -71.068800  Boston Metro     0.699062
# 4447            Boston  42.363000 -71.068800  Boston Metro     0.699062
#
# [4448 rows x 11 columns]

# %%
df_clean = df[df['emergency_department'] != 'All Visits']
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4370 entries, 1 to 4447
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   month                 4370 non-null   datetime64[ns]
#  1   emergency_department  4370 non-null   object
#  2   visits                4370 non-null   int64
#  3   pct_monthly_visits    4370 non-null   float64
#  4   average_los_hours     4370 non-null   float64
#  5   hospital_system       4370 non-null   object
#  6   city                  4370 non-null   object
#  7   latitude              4370 non-null   float64
#  8   longitude             4370 non-null   float64
#  9   region                4370 non-null   object
#  10  correlation           4370 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(4)
# memory usage: 409.7+ KB

# %%
hospital_counts = (
    df.groupby("emergency_department")["month"]
      .count()
      .sort_values()
)

hospital_counts
# Out:
# emergency_department
# North Adams Regional Hospital                12
# Steward Norwood Hospital                     21
# Signature Healthcare Brockton Hospital       61
# Nashoba Valley Medical Center                71
# Steward Carney Hospital                      71
# Lowell General Hospital                      78
# Marlborough Hospital                         78
# Martha's Vineyard Hospital                   78
# Massachusetts Eye and Ear Infirmary          78
# Massachusetts General Hospital               78
# MelroseWakefield Hospital                    78
# Mercy Medical Center                         78
# MetroWest Medical Center                     78
# Milford Regional Medical Center              78
# Morton Hospital                              78
# Mount Auburn Hospital                        78
# All Visits                                   78
# Lawrence General Hospital                    78
# Newton-Wellesley Hospital                    78
# North Shore Medical Center                   78
# Northeast Hospital                           78
# Saint Anne's Hospital                        78
# Saint Vincent Hospital                       78
# South Shore Hospital                         78
# Southcoast Hospitals Group                   78
# Sturdy Memorial Hospital                     78
# Tufts Medical Center                         78
# Nantucket Cottage Hospital                   78
# UMass Memorial Medical Center                78
# Lahey Hospital & Medical Center              78
# Holy Family Hospital                         78
# Anna Jaques Hospital                         78
# Athol Memorial Hospital                      78
# Baystate Franklin Medical Center             78
# Baystate Medical Center                      78
# Baystate Noble Hospital                      78
# Baystate Wing Hospital                       78
# Berkshire Medical Center                     78
# Beth Israel Deaconess Hospital - Milton      78
# Beth Israel Deaconess Hospital - Needham     78
# Beth Israel Deaconess Hospital - Plymouth    78
# Beth Israel Deaconess Medical Center         78
# Boston Children's Hospital                   78
# Holyoke Medical Center                       78
# Boston Medical Center                        78
# Boston Medical Center - South                78
# Brigham and Women's Faulkner Hospital        78
# Brigham and Women's Hospital                 78
# Cambridge Health Alliance                    78
# Cape Cod Hospital                            78
# Cooley Dickinson Hospital                    78
# Emerson Hospital                             78
# Fairview Hospital                            78
# Falmouth Hospital                            78
# Harrington Memorial Hospital                 78
# HealthAlliance-Clinton Hospital              78
# Heywood Hospital                             78
# Boston Medical Center - Brighton             78
# Winchester Hospital                          78
# Name: month, dtype: int64

# %% [markdown]
# ## Export cleaned data

# %%
# Save cleaned dataset for analysis notebooks
import os
os.makedirs("data/processed", exist_ok=True)
df_clean.to_csv("data/processed/df_clean.csv", index=False)
print("Saved: data/processed/df_clean.csv")
# Out:
# Saved: data/processed/df_clean.csv
